# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data = pd.read_csv('Francia.csv')
data.head(5)
# Out:
#    Unnamed: 0                                             name  host_id  \
# 0           0                    Duplex avec vue, centre ville   269557
# 1           1                  Nice Flat in the center of Lyon   411285
# 2           2               Centre of old town,home sweet home   660135
# 3           3              Bel apartment, 2 rooms, Lyon center   670404
# 4           4  Quartier Terreaux 4/6 pers. Hyper centre / Clim   832917
#
#     host_name  host_since        host_location  \
# 0    Isabelle  2010-10-24         Lyon, France
# 1  Clementine  2011-02-26         Lyon, France
# 2      Polali  2011-06-03         Lyon, France
# 3    Sandrine  2011-06-06         Lyon, France
# 4  Giuseppina  2011-07-18  Rhône-Alpes, France
#
#                                           host_about  host_response_time  \
# 0  I'm 47 years old. I enjoy books and arts. I'm ...  within a few hours
# 1  Je travaille dans le cinéma et je voyage beauc...      within an hour
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9891 entries, 0 to 9890
# Data columns (total 51 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Unnamed: 0                                     9891 non-null   int64
#  1   name                                           9891 non-null   object
#  2   host_id                                        9891 non-null   int64
#  3   host_name                                      9889 non-null   object
#  4   host_since                                     9889 non-null   object
#  5   host_location                                  8367 non-null   object
#  6   host_about                                     3825 non-null   object
#  7   host_response_time                             5235 non-null   object
#  8   host_response_rate                             5235 non-null   float64
# ...

# %%
#Asignamos el nombre "dataframe" a nuestra base de datos
dataframe=data

# %%
dataframe2=data

# %%
dataframe3=data

# %%
dataframe4=data

# %%
dataframe5=data

# %% [markdown]
# ***Función para identificar valores nulos***

# %%
def valores_nulos(dataframe):
    #Valores nulos por columna
    valores_nulos_cols = dataframe.isnull().sum()
    #Valores nulos por dataframe
    valores_nulos_df = dataframe.isnull().sum().sum()
    
    return("Valores nulos por columna", valores_nulos_cols,
            "Valores nulos por dataframe", valores_nulos_df)

# %%
# Llamamos a la función "cuenta_valores_nulos" y guardamos el retorno
valores_nulos(dataframe)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  name                                                0
#  host_id                                             0
#  host_name                                           2
#  host_since                                          2
#  host_location                                    1524
#  host_about                                       6066
#  host_response_time                               4656
#  host_response_rate                               4656
#  host_is_superhost                                 211
#  host_neighbourhood                               5544
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood_cleansed                              0
#  latitude                                            0
# ...

# %% [markdown]
# **Primer reemplazo: valores nulos con el método mediana para columnas tipo numeric**

# %%
def sustitución_mediana(dataframe):
    #Separo columnas cuantitativas del dataframe
    cuantitativas_con_nulos = dataframe.select_dtypes(include=['float64', 'int64','float','int'])
    #Separo columnas cualitativas del dataframe
    cualitativas = dataframe.select_dtypes(include=['object', 'datetime','category'])
    #Sustituir valores nulos con promedio o media
    cuantitativas = cuantitativas_con_nulos.fillna(round(cuantitativas_con_nulos.median(), 1))
    # Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

# %%
# Llamamos a la función "cuenta_valores_nulos" y guardamos el retorno
dataframe_sin_nulos= sustitución_mediana(dataframe)
dataframe_sin_nulos
# Out:
#       Unnamed: 0    host_id  host_response_rate  host_listings_count  \
# 0              0     269557                1.00                  1.0
# 1              1     411285                1.00                  1.0
# 2              2     660135                0.00                  1.0
# 3              3     670404                1.00                  1.0
# 4              4     832917                1.00                  5.0
# ...          ...        ...                 ...                  ...
# 9886        9886  651608878                0.87                 27.0
# 9887        9887  651608878                0.87                 27.0
# 9888        9888  666633599                1.00                  1.0
# 9889        9889   12466813                1.00                  1.0
# 9890        9890  417340177                1.00                 20.0
#
#       host_total_listings_count   latitude  longitude  accommodates  \
# 0                           3.0  45.763140   4.829760             5
# ...

# %%
valores_nulos(dataframe_sin_nulos)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  host_id                                             0
#  host_response_rate                                  0
#  host_listings_count                                 0
#  host_total_listings_count                           0
#  latitude                                            0
#  longitude                                           0
#  accommodates                                        0
#  bathrooms                                           0
#  bedrooms                                            0
#  beds                                                0
#  price                                               0
#  minimum_nights                                      0
#  maximum_nights                                      0
#  minimum_minimum_nights                              0
#  maximum_minimum_nights                              0
# ...

# %%
#Converti DF a CSV
dataframe_sin_nulos.to_csv('01_mediana.csv')

# %% [markdown]
# **Segundo ejercicio: método de "ffill" en columnas tipo object, datetime y category**

# %%
def sustitución_ffill(dataframe2):
    #Separo columnas cuantitativas del dataframe
    cuantitativas = dataframe2.select_dtypes(include=['float64', 'int64','float','int'])
    #Separo columnas cualitativas del dataframe
    cualitativas = dataframe2.select_dtypes(include=['object', 'datetime','category'])
    #Sustituir valores nulos con promedio o media
    cualitativas = cualitativas.fillna(method="ffill")
    # Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

# %%
# Llamamos a la función "cuenta_valores_nulos" y guardamos el retorno
dataframe_sin_nulos1= sustitución_ffill(dataframe2)
dataframe_sin_nulos1
valores_nulos(dataframe_sin_nulos1)
# Out:
# /var/folders/vk/htzm_z194jz4tflq2s4s86x80000gn/T/ipykernel_4238/3674674741.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cualitativas = cualitativas.fillna(method="ffill")
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  host_id                                             0
#  host_response_rate                               4656
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  latitude                                            0
#  longitude                                           0
#  accommodates                                        0
#  bathrooms                                        4425
#  bedrooms                                         1372
#  beds                                             4433
#  price                                            4421
# ...

# %%
#Converti DF a CSV
dataframe_sin_nulos1.to_csv('02_ffill.csv')

# %% [markdown]
# **Tercer ejercicio: método "bfill" para tipo object, datetime y category**

# %%
def sustitución_bfill(dataframe3):
    #Separo columnas cuantitativas del dataframe
    cuantitativas = dataframe3.select_dtypes(include=['float64', 'int64','float','int'])
    #Separo columnas cualitativas del dataframe
    cualitativas = dataframe3.select_dtypes(include=['object', 'datetime','category'])
    #Sustituir valores nulos con promedio o media
    cualitativas = cualitativas.fillna(method="bfill")
    # Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

# %%
# Llamamos a la función "cuenta_valores_nulos" y guardamos el retorno
dataframe_sin_nulos2= sustitución_ffill(dataframe3)
dataframe_sin_nulos2
valores_nulos(dataframe_sin_nulos2)
# Out:
# /var/folders/vk/htzm_z194jz4tflq2s4s86x80000gn/T/ipykernel_4238/3674674741.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cualitativas = cualitativas.fillna(method="ffill")
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  host_id                                             0
#  host_response_rate                               4656
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  latitude                                            0
#  longitude                                           0
#  accommodates                                        0
#  bathrooms                                        4425
#  bedrooms                                         1372
#  beds                                             4433
#  price                                            4421
# ...

# %%
#Converti DF a CSV
dataframe_sin_nulos2.to_csv('03_bfill.csv')

# %% [markdown]
# **Cuarto ejercicio con el método "string concreto" en columnas tipo object, datetime y category**

# %%
def sustitución_string_concreto(dataframe4):
    #Separo columnas cuantitativas del dataframe
    cuantitativas = dataframe3.select_dtypes(include=['float64', 'int64','float','int'])
    #Separo columnas cualitativas del dataframe
    cualitativas = dataframe3.select_dtypes(include=['object', 'datetime','category'])
    #Sustituir valores nulos con promedio o media
    cualitativas = cualitativas.fillna('Sin datos')
    # Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

# %%
# Llamamos a la función "cuenta_valores_nulos" y guardamos el retorno
dataframe_sin_nulos3= sustitución_string_concreto(dataframe4)
dataframe_sin_nulos3
valores_nulos(dataframe_sin_nulos3)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  host_id                                             0
#  host_response_rate                               4656
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  latitude                                            0
#  longitude                                           0
#  accommodates                                        0
#  bathrooms                                        4425
#  bedrooms                                         1372
#  beds                                             4433
#  price                                            4421
#  minimum_nights                                      0
#  maximum_nights                                      0
#  minimum_minimum_nights                              0
#  maximum_minimum_nights                              0
# ...

# %%
#Converti DF a CSV
dataframe_sin_nulos3.to_csv('04_string_sin_nulos.csv')

# %% [markdown]
# **Quinto ejercicio con el método de "constante" en columnas tipo numeric**

# %%
def constante(dataframe5):
    #Separo columnas cuantitativas del dataframe
    cuantitativas = dataframe3.select_dtypes(include=['float64', 'int64','float','int'])
    #Separo columnas cualitativas del dataframe
    cualitativas = dataframe3.select_dtypes(include=['object', 'datetime','category'])
    #Sustituir valores nulos con promedio o media
    cuantitativas = cuantitativas.fillna(50000)
    # Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

# %%
# Llamamos a la función "cuenta_valores_nulos" y guardamos el retorno
dataframe_sin_nulos4= constante(dataframe5)
dataframe_sin_nulos4
valores_nulos(dataframe_sin_nulos4)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                          0
#  host_id                                             0
#  host_response_rate                                  0
#  host_listings_count                                 0
#  host_total_listings_count                           0
#  latitude                                            0
#  longitude                                           0
#  accommodates                                        0
#  bathrooms                                           0
#  bedrooms                                            0
#  beds                                                0
#  price                                               0
#  minimum_nights                                      0
#  maximum_nights                                      0
#  minimum_minimum_nights                              0
#  maximum_minimum_nights                              0
# ...

# %%
#Converti DF a CSV
dataframe_sin_nulos4.to_csv('05_constante.csv')
